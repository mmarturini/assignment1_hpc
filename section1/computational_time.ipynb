# %%
import os
import numpy as np
import pandas as pd
import scipy as sp
from scipy.optimize import curve_fit
import matplotlib as mpl
import matplotlib.pyplot as plt

os.getcwd()
# Out:
# 'c:\\Users\\matte\\OneDrive\\Desktop\\Università\\Trieste\\Second_year\\HPC21\\Cozzini\\MPI\\Assignment1\\prob2'

# %%
oneD = np.array([1.238977, 1.186594, 1.201969, 1.189828, 1.182971, 1.18949])

p = np.array([1,2,4,8,12,24])

plt.figure()
plt.scatter(p, oneD, marker='.')
plt.plot(p, oneD)
plt.title('Domain: 2400x100x100')
plt.xlabel('Number of processes')
plt.ylabel("Computational time [s]")
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.
